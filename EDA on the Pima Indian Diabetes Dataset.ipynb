# %%
import pandas as pd

# %%
pima = pd.read_csv("C://Users/kiimi/Downloads/Pima Indian Diabetes Dataset/diabetes.csv")

# %%
pima.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
pima.shape
# Out:
# (768, 9)

# %%
pima.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
pima[pima.Pregnancies > 3].count()
# Out:
# Pregnancies                 344
# Glucose                     344
# BloodPressure               344
# SkinThickness               344
# Insulin                     344
# BMI                         344
# DiabetesPedigreeFunction    344
# Age                         344
# Outcome                     344
# dtype: int64

# %%
pima[pima['Glucose'] > 100]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
pima.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
pima[pima['Pregnancies'] < 10].count()
# Out:
# Pregnancies                 710
# Glucose                     710
# BloodPressure               710
# SkinThickness               710
# Insulin                     710
# BMI                         710
# DiabetesPedigreeFunction    710
# Age                         710
# Outcome                     710
# dtype: int64

# %%
pima[(pima['Glucose'] < 100) & (pima['BloodPressure'] > 80)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 21             8       99             84              0        0  35.4
# 33             6       92             92              0        0  19.9
# 106            1       96            122              0        0  22.4
# 109            0       95             85             25       36  37.4
# 290            0       78             88             29       40  36.9
# 302            5       77             82             41       42  35.8
# 352            3       61             82             28        0  34.4
# 368            3       81             86             16       66  27.5
# 376            0       98             82             15       84  25.2
# 379            0       93            100             39       72  43.4
# 429            1       95             82             25      180  35.0
# 483            0       84             82             31      125  38.2
# ...

# %%
pima.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
pima.Age.value_counts()
# Out:
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 32    16
# 36    16
# 38    16
# 45    15
# 34    14
# 40    13
# 43    13
# 46    13
# 39    12
# 35    10
# 50     8
# 44     8
# 51     8
# 52     8
# 58     7
# 47     6
# 54     6
# 57     5
# 60     5
# 48     5
# 49     5
# 53     5
# 55     4
# 62     4
# 63     4
# 66     4
# 56     3
# 59     3
# 65     3
# 67     3
# 61     2
# 69     2
# 72     1
# 64     1
# 68     1
# 70     1
# 81     1
# Name: Age, dtype: int64

# %%
pima.Age.value_counts().plot(kind='hist')

# %%
pima.Pregnancies.value_counts()
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64

# %%
pima.Pregnancies.value_counts(normalize=True)
# Out:
# 1     0.175781
# 0     0.144531
# 2     0.134115
# 3     0.097656
# 4     0.088542
# 5     0.074219
# 6     0.065104
# 7     0.058594
# 8     0.049479
# 9     0.036458
# 10    0.031250
# 11    0.014323
# 13    0.013021
# 12    0.011719
# 14    0.002604
# 15    0.001302
# 17    0.001302
# Name: Pregnancies, dtype: float64

# %%
# %matplotlib inline

# %%
pima.Pregnancies.value_counts().plot(kind='bar')

# %%
pima.groupby('Age').Pregnancies.mean()
# Out:
# Age
# 21    1.079365
# 22    1.555556
# 23    1.578947
# 24    1.891304
# 25    1.770833
# 26    1.969697
# 27    2.562500
# 28    3.028571
# 29    3.310345
# 30    3.619048
# 31    3.875000
# 32    4.437500
# 33    4.058824
# 34    5.857143
# 35    5.000000
# 36    5.187500
# 37    5.263158
# 38    6.875000
# 39    7.416667
# 40    6.230769
# 41    6.500000
# 42    6.888889
# 43    7.769231
# 44    7.250000
# 45    7.333333
# 46    6.384615
# 47    8.333333
# 48    8.800000
# 49    7.600000
# 50    6.750000
# 51    8.625000
# 52    4.625000
# 53    5.400000
# 54    7.000000
# 55    5.500000
# 56    8.000000
# 57    8.800000
# 58    7.142857
# 59    2.333333
# 60    6.000000
# 61    5.500000
# 62    3.750000
# 63    5.500000
# 64    8.000000
# 65    3.333333
# 66    5.000000
# 67    4.000000
# 68    8.000000
# 69    5.000000
# 70    4.000000
# 72    2.000000
# 81    9.000000
# Name: Pregnancies, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(pima['Age'],pima['Pregnancies'])

# %%
pima.groupby('BloodPressure').Insulin.mean()
# Out:
# BloodPressure
# 0        0.000000
# 24      25.000000
# 30      91.000000
# 38     120.000000
# 40     168.000000
# 44      71.750000
# 46     209.000000
# 48      87.000000
# 50     124.461538
# 52      91.454545
# 54      76.818182
# 55       0.000000
# 56      68.500000
# 58     106.904762
# 60     105.702703
# 61       0.000000
# 62      88.705882
# 64      90.139535
# 65      28.000000
# 66      68.700000
# 68      89.088889
# 70      94.964912
# 72      71.863636
# 74      73.442308
# 75       0.000000
# 76      88.615385
# 78      66.755556
# 80      62.925000
# 82     109.900000
# 84     118.956522
# 85      22.666667
# 86      86.047619
# 88     101.520000
# 90     116.136364
# 92      19.375000
# 94      48.500000
# 95       0.000000
# 96       0.000000
# 98      19.333333
# 100    104.000000
# 102    140.000000
# 104      0.000000
# 106     93.333333
# 108      0.000000
# 110    123.333333
# 114      0.000000
# 122      0.000000
# Name: Insulin, dtype: float64
